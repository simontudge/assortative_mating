# %% [markdown]
# #Sweep through both ST space and HD space, using purely the theoretical results

# %% [markdown]
# Using the game theory helper functions perform a theoretical sweep through both ST space and HD space, just to check if these functions are correct.

# %%
from assortative_mating.helpers.game_theory_helpers import *
import sweepy
# %matplotlib inline
# Out:
# Happy sweeping!

# %%
sweepy.sweep_func( ESS, [ ['T', 0,2,101], ['S', -1, 1, 101] ] );
# Out:
# /home/simontudge/anaconda3/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
sweepy.sweep_func(ESS_h_s_delta, [ ['h', 0, 1, 101], ['delta', 0, 1, 101 ] ], fixed_params = {'s':1.});
# Out:
# /home/simontudge/anaconda3/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
